# %% [markdown]
# Problems running into during this scraping and how they're solved:
#
#     1) course descriptions are in a PDF. looks like I'll need to learn a PDF scraper, maybe PyPDF2 import PdfFileReader?

# %%
from jupyterthemes import jtplot
jtplot.style()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# main website: https://www.vanderbilt.edu/
#
#
# undergraduate programs: https://www.vanderbilt.edu/academics/program-finder/?degrees=bachelors%2Conline
#
#
# GRADUATE programs: https://www.vanderbilt.edu/academics/program-finder/?degrees=masters%2Cdoctoral%2Conline
#
#
# course descriptions pdf: https://www.vanderbilt.edu/catalogs/documents/UGAD.pdf#contents
#
#
# looks like i'll need to use PyPDF2 import PdfFileReader and maybe import io? look at url below
#
#
# helpful url?: https://stackoverflow.com/questions/59130672/how-to-scrape-pdfs-using-python-specific-content-only

# %%
vandy_main = 'https://www.vanderbilt.edu/'
response_main = requests.get(vandy_main)
response_main.status_code
# Out:
# 200

# %%
print(type(response_main))
response_main.content
# Out:
# <class 'requests.models.Response'>
# ...

# %%
soup_main = BeautifulSoup(response_main.content, 'lxml')
print(soup_main.title)
# Out:
# <title>Vanderbilt University</title>

# %%
print(soup_main)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]--><!--[if IE 9]><html class="no-js no-svg ie ie9 lt-ie9 lt-ie8" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js no-svg" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"> <!--<![endif]-->
# <head>
# <script>
#         var searchMethod = '';
#         var VUWPurl = 'https://www.vanderbilt.edu';
#                             <!-- Google Tag Manager -->
#             (function(v,a,n,d,y){v[d]=v[d]||[];v[d].push({'gtm.start':
# ...

# %%
vandy_programs = 'https://www.vanderbilt.edu/academics/program-finder/?degrees=bachelors%2Conline'
response_programs = requests.get(vandy_programs)
response_programs.status_code
# Out:
# 200

# %%
print(type(response_programs))
response_programs.content
# Out:
# <class 'requests.models.Response'>
# ...

# %%
soup_programs = BeautifulSoup(response_programs.content, 'lxml')
print(soup_programs.title)
# Out:
# <title>Program Finder | Vanderbilt University</title>

# %%
print(soup_programs)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]--><!--[if IE 9]><html class="no-js no-svg ie ie9 lt-ie9 lt-ie8" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js no-svg" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"> <!--<![endif]-->
# <head>
# <script>
#         var searchMethod = '';
#         var VUWPurl = 'https://www.vanderbilt.edu';
#                             <!-- Google Tag Manager -->
#             (function(v,a,n,d,y){v[d]=v[d]||[];v[d].push({'gtm.start':
# ...

# %% [markdown]
# FROM HERE DOWN I NEED TO LOOK INTO WEBSCRAPING A PDF!!!

# %%
# vandy_courses_1 = NEED TO SCRAPE FROM PDF
# response_courses_1 = requests.get(vandy_courses_1)
# response_courses_1.status_code

# %%
# print(type(response_courses_1))
# response_courses_1.content

# %%
# soup_courses_1 = BeautifulSoup(response_courses_1.content)
# print(soup_courses_1.title)

# %%
# print(soup_courses_1)
